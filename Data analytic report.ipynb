# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
shankar = pd.read_csv("data.csv")

# %%
shankar
# Out:
#      Person_ID  Age  Gender  Height_cm  Weight_kg    BMI    Country  \
# 0       P00001   76  Female      158.8       62.1  24.63      Italy
# 1       P00002   49  Female      160.9       68.5  26.45        USA
# 2       P00003   51  Female      151.9       54.8  23.77     Mexico
# 3       P00004   48    Male      167.6       81.3  28.93  Australia
# 4       P00005   68  Female      171.9       75.4  25.51        USA
# ...        ...  ...     ...        ...        ...    ...        ...
# 9995    P09996   66    Male      170.2       86.4  29.84    Nigeria
# 9996    P09997   70    Male      182.3       86.9  26.14     Canada
# 9997    P09998   29    Male      170.4       81.2  27.96      Italy
# 9998    P09999   22    Male      186.5       78.3  22.52      India
# 9999    P10000   58    Male      177.8       63.9  20.22     Brazil
#
#              Occupation Marital_Status Wake_Up_Time  ... Obesity_Risk  \
# 0          Entrepreneur        Widowed        08:59  ...          Low
# ...

# %%
plt.plot(shankar["Age"], shankar["BMI"])
plt.xlabel("Age")
plt.ylabel("BMI")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
shankar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 64 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Person_ID                       10000 non-null  object
#  1   Age                             10000 non-null  int64
#  2   Gender                          10000 non-null  object
#  3   Height_cm                       10000 non-null  float64
#  4   Weight_kg                       10000 non-null  float64
#  5   BMI                             10000 non-null  float64
#  6   Country                         10000 non-null  object
#  7   Occupation                      10000 non-null  object
#  8   Marital_Status                  10000 non-null  object
#  9   Wake_Up_Time                    10000 non-null  object
#  10  Sleep_Time                      10000 non-null  object
#  11  Sleep_Duration_Hours            10000 non-null  float64
# ...

# %%
shankar.isnull().sum()
# Out:
# Person_ID              0
# Age                    0
# Gender                 0
# Height_cm              0
# Weight_kg              0
#                       ..
# Health_Score           0
# Fitness_Level          0
# Healthy_Aging_Score    0
# Wellness_Category      0
# Early_Waker            0
# Length: 64, dtype: int64

# %%
#number of people in each occupation?

# %%
occupation_count= shankar['Occupation'].value_counts()

# %% [raw]
# plt.figure(figsize= (6,7))

# %%
occupation_count.plot(kind= 'bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
occuaption_count = shankar['Occupation'].value_counts()
plt.pie(occupation_count,
        labels=occupation_count.index,
        autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1e2b3322710>,
# ...
#  [Text(1.0487995877121719, 0.33169176175295406, 'Software Engineer'),
#   Text(0.6714638024160586, 0.8712843175708882, 'Student'),
#   Text(0.07424211449495746, 1.097491735019138, 'Teacher'),
#   Text(-0.5033881201566188, 0.9780595076400953, 'Retired'),
#   Text(-0.916532051875612, 0.6082507689141714, 'Manager'),
#   Text(-1.093877365283857, 0.11589784173852238, 'Freelancer'),
#   Text(-1.0350857977022434, -0.3722867059070341, 'Nurse'),
#   Text(-0.7743888907879695, -0.7812309810959742, 'Accountant'),
#   Text(-0.3926988522821718, -1.0275152609164815, 'Doctor'),
#   Text(0.021078692296442346, -1.0997980217890337, 'Entrepreneur'),
#   Text(0.41295730030946143, -1.0195421855524769, 'Laborer'),
#   Text(0.7271835922863277, -0.8253508484938706, 'Lawyer'),
#   Text(0.9422109120178677, -0.567660635656955, 'Chef'),
#   Text(1.0528847590425852, -0.3184865525824248, 'Athlete'),
#   Text(1.0949541767385034, -0.10523949279099801, 'Artist')],
# ...

# %%
#2

gender_count = df['Gender'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(gender_count,
        labels=gender_count.index,
        autopct='%1.1f%%')

plt.title("Gender Distribution")
plt.show()

# %%
plt.figure(figsize=(3,8))

# %%
#different heights of persons in a company

# %%
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
height_count = shankar['Height_cm'].value_counts()

# %%
plt.figure(figsize= (6,7))
height_count.plot(kind='line')
plt.xlabel("height")
plt.title("different height of people")
# Out:
# Text(0.5, 1.0, 'different height of people')

# %%
scatter_ss = shankar['Age'],shankar['Height_cm']

# %%
plt.figure(figsize= (6,8))
plt.scatter( shankar['Age'],
             shankar['Height_cm'])
plt.xlabel("Age")
plt.ylabel("Height")
plt.title("Difference between height and age of person is company")
plt.show()
